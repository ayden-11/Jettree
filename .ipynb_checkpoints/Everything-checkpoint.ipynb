# %%
import ROOT, math, numpy as np
import random
# Out:
# Welcome to JupyROOT 6.26/06

# %%
File = ROOT.TFile("LEP1MC1994_recons_aftercut-001.root")
#no detector simulation for matchbox
File.ls()
# Out:
# TFile**		LEP1MC1994_recons_aftercut-001.root
#  TFile*		LEP1MC1994_recons_aftercut-001.root
#   KEY: TTree	t;1	t
#   KEY: TTree	akR4ESchemeJetTree;1	akR4ESchemeJetTree
#   KEY: TTree	akR4WTAmodpSchemeJetTree;1	akR4WTAmodpSchemeJetTree
#   KEY: TTree	akR8ESchemeJetTree;1	akR8ESchemeJetTree
#   KEY: TTree	akR8WTAmodpSchemeJetTree;1	akR8WTAmodpSchemeJetTree
#   KEY: TTree	BoostedWTAR8Evt;1	BoostedWTAR8Evt
#   KEY: TTree	ktN2ESchemeJetTree;1	ktN2ESchemeJetTree
#   KEY: TTree	ktN2WTAmodpSchemeJetTree;1	ktN2WTAmodpSchemeJetTree
#   KEY: TTree	BoostedWTAktN2Evt;1	BoostedWTAktN2Evt
#   KEY: TTree	ktN3ESchemeJetTree;1	ktN3ESchemeJetTree
#   KEY: TTree	ktN3WTAmodpSchemeJetTree;1	ktN3WTAmodpSchemeJetTree
#   KEY: TTree	tgen;1	tgen
#   KEY: TTree	tgenBefore;1	tgenBefore
#   KEY: TTree	akR4ESchemeGenJetTree;1	akR4ESchemeGenJetTree
#   KEY: TTree	akR4ESchemeGenJetBeforeTree;1	akR4ESchemeGenJetBeforeTree
#   KEY: TTree	akR4WTAmodpSchemeGenJetTree;1	akR4WTAmodpSchemeGenJetTree
#   KEY: TTree	akR4WTAmodpSchemeGenJetBeforeTree;1	akR4WTAmodpSchemeGenJetBeforeTree
#   KEY: TTree	akR8ESchemeGenJetTree;1	akR8ESchemeGenJetTree
#   KEY: TTree	akR8ESchemeGenJetBeforeTree;1	akR8ESchemeGenJetBeforeTree
#   KEY: TTree	akR8WTAmodpSchemeGenJetTree;1	akR8WTAmodpSchemeGenJetTree
#   KEY: TTree	akR8WTAmodpSchemeGenJetBeforeTree;1	akR8WTAmodpSchemeGenJetBeforeTree
#   KEY: TTree	genBoostedWTAR8Evt;1	genBoostedWTAR8Evt
#   KEY: TTree	genBoostedWTAR8BeforeEvt;1	genBoostedWTAR8BeforeEvt
#   KEY: TTree	ktN2ESchemeGenJetTree;1	ktN2ESchemeGenJetTree
#   KEY: TTree	ktN2ESchemeGenJetBeforeTree;1	ktN2ESchemeGenJetBeforeTree
#   KEY: TTree	ktN2WTAmodpSchemeGenJetTree;1	ktN2WTAmodpSchemeGenJetTree
#   KEY: TTree	ktN2WTAmodpSchemeGenJetBeforeTree;1	ktN2WTAmodpSchemeGenJetBeforeTree
#   KEY: TTree	genBoostedWTAktN2Evt;1	genBoostedWTAktN2Evt
#   KEY: TTree	genBoostedWTAktN2BeforeEvt;1	genBoostedWTAktN2BeforeEvt
#   KEY: TTree	ktN3ESchemeGenJetTree;1	ktN3ESchemeGenJetTree
#   KEY: TTree	ktN3ESchemeGenJetBeforeTree;1	ktN3ESchemeGenJetBeforeTree
#   KEY: TTree	ktN3WTAmodpSchemeGenJetTree;1	ktN3WTAmodpSchemeGenJetTree
#   KEY: TTree	ktN3WTAmodpSchemeGenJetBeforeTree;1	ktN3WTAmodpSchemeGenJetBeforeTree

# %%
Tree = File.Get("t")
Tree.Print()
# Out:
# ******************************************************************************
# *Tree    :t         : t                                                      *
# *Entries :    19158 : Total =       195218698 bytes  File  Size =  112616563 *
# *        :          : Tree compression factor =   1.73                       *
# ******************************************************************************
# *Br    0 :EventNo   : EventNo/I                                              *
# *Entries :    19158 : Total  Size=      77409 bytes  File Size  =      43093 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.78     *
# *............................................................................*
# *Br    1 :RunNo     : RunNo/I                                                *
# *Entries :    19158 : Total  Size=      77393 bytes  File Size  =        793 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  96.98     *
# *............................................................................*
# *Br    2 :year      : year/I                                                 *
# *Entries :    19158 : Total  Size=      77385 bytes  File Size  =        796 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  96.61     *
# *............................................................................*
# *Br    3 :subDir    : subDir/I                                               *
# *Entries :    19158 : Total  Size=      77401 bytes  File Size  =        743 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression= 103.52     *
# *............................................................................*
# *Br    4 :process   : process/I                                              *
# *Entries :    19158 : Total  Size=      77409 bytes  File Size  =        747 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression= 102.97     *
# *............................................................................*
# *Br    5 :isMC      : isMC/O                                                 *
# *Entries :    19158 : Total  Size=      19905 bytes  File Size  =        487 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  39.90     *
# *............................................................................*
# *Br    6 :uniqueID  : uniqueID/l                                             *
# *Entries :    19158 : Total  Size=     154129 bytes  File Size  =      43639 *
# *Baskets :        5 : Basket Size=      80896 bytes  Compression=   3.52     *
# *............................................................................*
# *Br    7 :Energy    : Energy/F                                               *
# *Entries :    19158 : Total  Size=      77401 bytes  File Size  =        808 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  95.19     *
# *............................................................................*
# *Br    8 :bFlag     : bFlag/I                                                *
# *Entries :    19158 : Total  Size=      77393 bytes  File Size  =        800 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  96.14     *
# *............................................................................*
# *Br    9 :particleWeight : particleWeight/F                                  *
# *Entries :    19158 : Total  Size=      77465 bytes  File Size  =        836 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  92.04     *
# *............................................................................*
# *Br   10 :bx        : bx/F                                                   *
# *Entries :    19158 : Total  Size=      77369 bytes  File Size  =        792 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  97.09     *
# *............................................................................*
# *Br   11 :by        : by/F                                                   *
# *Entries :    19158 : Total  Size=      77369 bytes  File Size  =        792 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  97.09     *
# *............................................................................*
# *Br   12 :ebx       : ebx/F                                                  *
# *Entries :    19158 : Total  Size=      77377 bytes  File Size  =        796 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  96.61     *
# *............................................................................*
# *Br   13 :eby       : eby/F                                                  *
# *Entries :    19158 : Total  Size=      77377 bytes  File Size  =        796 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=  96.61     *
# *............................................................................*
# *Br   14 :nParticle : nParticle/I                                            *
# *Entries :    19158 : Total  Size=      77425 bytes  File Size  =      21780 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   3.53     *
# *............................................................................*
# *Br   15 :px        : px[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =    1637457 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.43     *
# *............................................................................*
# *Br   16 :py        : py[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =    1634423 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   17 :pz        : pz[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =    1608870 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.46     *
# *............................................................................*
# *Br   18 :pt        : pt[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =    1604711 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.46     *
# *............................................................................*
# *Br   19 :pmag      : pmag[nParticle]/F                                      *
# *Entries :    19158 : Total  Size=    2349860 bytes  File Size  =    1637001 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.43     *
# *............................................................................*
# *Br   20 :rap       : rap[nParticle]/F                                       *
# *Entries :    19158 : Total  Size=    2349833 bytes  File Size  =    1438480 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.63     *
# *............................................................................*
# *Br   21 :eta       : eta[nParticle]/F                                       *
# *Entries :    19158 : Total  Size=    2349833 bytes  File Size  =    1441163 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.63     *
# *............................................................................*
# *Br   22 :theta     : theta[nParticle]/F                                     *
# *Entries :    19158 : Total  Size=    2349887 bytes  File Size  =    1406554 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.67     *
# *............................................................................*
# *Br   23 :phi       : phi[nParticle]/F                                       *
# *Entries :    19158 : Total  Size=    2349833 bytes  File Size  =    1628781 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   24 :mass      : mass[nParticle]/F                                      *
# *Entries :    19158 : Total  Size=    2349860 bytes  File Size  =     354716 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   6.62     *
# *............................................................................*
# *Br   25 :charge    : charge[nParticle]/S                                    *
# *Entries :    19158 : Total  Size=    1213722 bytes  File Size  =     250077 *
# *Baskets :       14 : Basket Size=     359936 bytes  Compression=   4.85     *
# *............................................................................*
# *Br   26 :pwflag    : pwflag[nParticle]/S                                    *
# *Entries :    19158 : Total  Size=    1213722 bytes  File Size  =     193052 *
# *Baskets :       14 : Basket Size=     359936 bytes  Compression=   6.28     *
# *............................................................................*
# *Br   27 :pid       : pid[nParticle]/I                                       *
# *Entries :    19158 : Total  Size=    2349826 bytes  File Size  =      70646 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=  33.25     *
# *............................................................................*
# *Br   28 :d0        : d0[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =     854904 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   2.75     *
# *............................................................................*
# *Br   29 :z0        : z0[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =    1072756 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   2.19     *
# *............................................................................*
# *Br   30 :highPurity : highPurity[nParticle]/O                               *
# *Entries :    19158 : Total  Size=     645629 bytes  File Size  =      86533 *
# *Baskets :        9 : Basket Size=     210432 bytes  Compression=   7.45     *
# *............................................................................*
# *Br   31 :ntpc      : ntpc[nParticle]/S                                      *
# *Entries :    19158 : Total  Size=    1213686 bytes  File Size  =     389175 *
# *Baskets :       14 : Basket Size=     359936 bytes  Compression=   3.12     *
# *............................................................................*
# *Br   32 :nitc      : nitc[nParticle]/S                                      *
# *Entries :    19158 : Total  Size=    1213686 bytes  File Size  =     350414 *
# *Baskets :       14 : Basket Size=     359936 bytes  Compression=   3.46     *
# *............................................................................*
# *Br   33 :nvdet     : nvdet[nParticle]/S                                     *
# *Entries :    19158 : Total  Size=    1213704 bytes  File Size  =     259738 *
# *Baskets :       14 : Basket Size=     359936 bytes  Compression=   4.67     *
# *............................................................................*
# *Br   34 :vx        : vx[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =      70593 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=  33.27     *
# *............................................................................*
# *Br   35 :vy        : vy[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =      70593 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=  33.27     *
# *............................................................................*
# *Br   36 :vz        : vz[nParticle]/F                                        *
# *Entries :    19158 : Total  Size=    2349806 bytes  File Size  =      70593 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=  33.27     *
# *............................................................................*
# *Br   37 :weight    : weight[nParticle]/F                                    *
# *Entries :    19158 : Total  Size=    2349914 bytes  File Size  =     968818 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   2.42     *
# *............................................................................*
# *Br   38 :pt_wrtThr : pt_wrtThr[nParticle]/F                                 *
# *Entries :    19158 : Total  Size=    2349995 bytes  File Size  =    1372963 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   39 :eta_wrtThr : eta_wrtThr[nParticle]/F                               *
# *Entries :    19158 : Total  Size=    2350022 bytes  File Size  =    1695176 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   40 :rap_wrtThr : rap_wrtThr[nParticle]/F                               *
# *Entries :    19158 : Total  Size=    2350022 bytes  File Size  =    1688031 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   41 :theta_wrtThr : theta_wrtThr[nParticle]/F                           *
# *Entries :    19158 : Total  Size=    2350076 bytes  File Size  =    1459420 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   42 :phi_wrtThr : phi_wrtThr[nParticle]/F                               *
# *Entries :    19158 : Total  Size=    2350022 bytes  File Size  =    1627923 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   43 :pt_wrtThrPerp : pt_wrtThrPerp[nParticle]/F                         *
# *Entries :    19158 : Total  Size=    2350103 bytes  File Size  =    1637447 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.43     *
# *............................................................................*
# *Br   44 :eta_wrtThrPerp : eta_wrtThrPerp[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1362265 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   45 :rap_wrtThrPerp : rap_wrtThrPerp[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1356361 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.73     *
# *............................................................................*
# *Br   46 :theta_wrtThrPerp : theta_wrtThrPerp[nParticle]/F                   *
# *Entries :    19158 : Total  Size=    2350184 bytes  File Size  =    1317388 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.78     *
# *............................................................................*
# *Br   47 :phi_wrtThrPerp : phi_wrtThrPerp[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1519335 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   48 :pt_wrtChThr : pt_wrtChThr[nParticle]/F                             *
# *Entries :    19158 : Total  Size=    2350049 bytes  File Size  =    1378551 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.70     *
# *............................................................................*
# *Br   49 :eta_wrtChThr : eta_wrtChThr[nParticle]/F                           *
# *Entries :    19158 : Total  Size=    2350076 bytes  File Size  =    1691953 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   50 :rap_wrtChThr : rap_wrtChThr[nParticle]/F                           *
# *Entries :    19158 : Total  Size=    2350076 bytes  File Size  =    1683325 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.40     *
# *............................................................................*
# *Br   51 :theta_wrtChThr : theta_wrtChThr[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1460691 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   52 :phi_wrtChThr : phi_wrtChThr[nParticle]/F                           *
# *Entries :    19158 : Total  Size=    2350076 bytes  File Size  =    1627969 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   53 :pt_wrtChThrPerp : pt_wrtChThrPerp[nParticle]/F                     *
# *Entries :    19158 : Total  Size=    2350157 bytes  File Size  =    1636898 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   54 :eta_wrtChThrPerp : eta_wrtChThrPerp[nParticle]/F                   *
# *Entries :    19158 : Total  Size=    2350184 bytes  File Size  =    1365019 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   55 :rap_wrtChThrPerp : rap_wrtChThrPerp[nParticle]/F                   *
# *Entries :    19158 : Total  Size=    2350184 bytes  File Size  =    1359682 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.73     *
# *............................................................................*
# *Br   56 :theta_wrtChThrPerp : theta_wrtChThrPerp[nParticle]/F               *
# *Entries :    19158 : Total  Size=    2350238 bytes  File Size  =    1319202 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.78     *
# *............................................................................*
# *Br   57 :phi_wrtChThrPerp : phi_wrtChThrPerp[nParticle]/F                   *
# *Entries :    19158 : Total  Size=    2350184 bytes  File Size  =    1520013 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   58 :pt_wrtNeuThr : pt_wrtNeuThr[nParticle]/F                           *
# *Entries :    19158 : Total  Size=    2350076 bytes  File Size  =    1390045 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.69     *
# *............................................................................*
# *Br   59 :eta_wrtNeuThr : eta_wrtNeuThr[nParticle]/F                         *
# *Entries :    19158 : Total  Size=    2350103 bytes  File Size  =    1689221 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   60 :rap_wrtNeuThr : rap_wrtNeuThr[nParticle]/F                         *
# *Entries :    19158 : Total  Size=    2350103 bytes  File Size  =    1679917 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.40     *
# *............................................................................*
# *Br   61 :theta_wrtNeuThr : theta_wrtNeuThr[nParticle]/F                     *
# *Entries :    19158 : Total  Size=    2350157 bytes  File Size  =    1462399 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   62 :phi_wrtNeuThr : phi_wrtNeuThr[nParticle]/F                         *
# *Entries :    19158 : Total  Size=    2350103 bytes  File Size  =    1628197 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   63 :pt_wrtNeuThrPerp : pt_wrtNeuThrPerp[nParticle]/F                   *
# *Entries :    19158 : Total  Size=    2350184 bytes  File Size  =    1637051 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   64 :eta_wrtNeuThrPerp : eta_wrtNeuThrPerp[nParticle]/F                 *
# *Entries :    19158 : Total  Size=    2350211 bytes  File Size  =    1365498 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   65 :theta_wrtNeuThrPerp : theta_wrtNeuThrPerp[nParticle]/F             *
# *Entries :    19158 : Total  Size=    2350265 bytes  File Size  =    1320963 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.78     *
# *............................................................................*
# *Br   66 :phi_wrtNeuThrPerp : phi_wrtNeuThrPerp[nParticle]/F                 *
# *Entries :    19158 : Total  Size=    2350211 bytes  File Size  =    1525186 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.54     *
# *............................................................................*
# *Br   67 :rap_wrtNeuThrPerp : rap_wrtNeuThrPerp[nParticle]/F                 *
# *Entries :    19158 : Total  Size=    2350211 bytes  File Size  =    1592623 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.48     *
# *............................................................................*
# *Br   68 :pt_wrtThrCorr : pt_wrtThrCorr[nParticle]/F                         *
# *Entries :    19158 : Total  Size=    2350103 bytes  File Size  =    1372829 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   69 :eta_wrtThrCorr : eta_wrtThrCorr[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1695118 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   70 :rap_wrtThrCorr : rap_wrtThrCorr[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1688233 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   71 :theta_wrtThrCorr : theta_wrtThrCorr[nParticle]/F                   *
# *Entries :    19158 : Total  Size=    2350184 bytes  File Size  =    1460303 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   72 :phi_wrtThrCorr : phi_wrtThrCorr[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1627126 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   73 :pt_wrtThrCorrPerp : pt_wrtThrCorrPerp[nParticle]/F                 *
# *Entries :    19158 : Total  Size=    2350211 bytes  File Size  =    1637781 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.43     *
# *............................................................................*
# *Br   74 :eta_wrtThrCorrPerp : eta_wrtThrCorrPerp[nParticle]/F               *
# *Entries :    19158 : Total  Size=    2350238 bytes  File Size  =    1362313 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   75 :rap_wrtThrCorrPerp : rap_wrtThrCorrPerp[nParticle]/F               *
# *Entries :    19158 : Total  Size=    2350238 bytes  File Size  =    1356719 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.73     *
# *............................................................................*
# *Br   76 :theta_wrtThrCorrPerp : theta_wrtThrCorrPerp[nParticle]/F           *
# *Entries :    19158 : Total  Size=    2350292 bytes  File Size  =    1317259 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.78     *
# *............................................................................*
# *Br   77 :phi_wrtThrCorrPerp : phi_wrtThrCorrPerp[nParticle]/F               *
# *Entries :    19158 : Total  Size=    2350238 bytes  File Size  =    1519791 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   78 :pt_wrtThrCorrInverse : pt_wrtThrCorrInverse[nParticle]/F           *
# *Entries :    19158 : Total  Size=    2350292 bytes  File Size  =    1373224 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   79 :eta_wrtThrCorrInverse : eta_wrtThrCorrInverse[nParticle]/F         *
# *Entries :    19158 : Total  Size=    2350319 bytes  File Size  =    1694756 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   80 :rap_wrtThrCorrInverse : rap_wrtThrCorrInverse[nParticle]/F         *
# *Entries :    19158 : Total  Size=    2350319 bytes  File Size  =    1687454 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   81 :theta_wrtThrCorrInverse : theta_wrtThrCorrInverse[nParticle]/F     *
# *Entries :    19158 : Total  Size=    2350373 bytes  File Size  =    1459845 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   82 :phi_wrtThrCorrInverse : phi_wrtThrCorrInverse[nParticle]/F         *
# *Entries :    19158 : Total  Size=    2350319 bytes  File Size  =    1627167 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   83 :pt_wrtThrCorrInversePerp : pt_wrtThrCorrInversePerp[nParticle]/F   *
# *Entries :    19158 : Total  Size=    2350400 bytes  File Size  =    1637550 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.43     *
# *............................................................................*
# *Br   84 :eta_wrtThrCorrInversePerp : eta_wrtThrCorrInversePerp[nParticle]/F *
# *Entries :    19158 : Total  Size=    2350427 bytes  File Size  =    1362783 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   85 :rap_wrtThrCorrInversePerp : rap_wrtThrCorrInversePerp[nParticle]/F *
# *Entries :    19158 : Total  Size=    2350427 bytes  File Size  =    1356266 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.73     *
# *............................................................................*
# *Br   86 :theta_wrtThrCorrInversePerp :                                      *
# *         | theta_wrtThrCorrInversePerp[nParticle]/F                         *
# *Entries :    19158 : Total  Size=    2350481 bytes  File Size  =    1317734 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.78     *
# *............................................................................*
# *Br   87 :phi_wrtThrCorrInversePerp : phi_wrtThrCorrInversePerp[nParticle]/F *
# *Entries :    19158 : Total  Size=    2350427 bytes  File Size  =    1519583 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   88 :pt_wrtThrMissP : pt_wrtThrMissP[nParticle]/F                       *
# *Entries :    19158 : Total  Size=    2350130 bytes  File Size  =    1373665 *
# *Baskets :       23 : Basket Size=     658944 bytes  Compression=   1.71     *
# *............................................................................*
# *Br   89 :eta_wrtThrMissP : eta_wrtThrMissP[nParticle]/F                     *
# *Entries :    19158 : Total  Size=    2350157 bytes  File Size  =    1694991 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   90 :rap_wrtThrMissP : rap_wrtThrMissP[nParticle]/F                     *
# *Entries :    19158 : Total  Size=    2350157 bytes  File Size  =    1687628 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.39     *
# *............................................................................*
# *Br   91 :theta_wrtThrMissP : theta_wrtThrMissP[nParticle]/F                 *
# *Entries :    19158 : Total  Size=    2350211 bytes  File Size  =    1460760 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.61     *
# *............................................................................*
# *Br   92 :phi_wrtThrMissP : phi_wrtThrMissP[nParticle]/F                     *
# *Entries :    19158 : Total  Size=    2350157 bytes  File Size  =    1627553 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.44     *
# *............................................................................*
# *Br   93 :pt_wrtThrMissPPerp : pt_wrtThrMissPPerp[nParticle]/F               *
# *Entries :    19158 : Total  Size=    2350238 bytes  File Size  =    1637618 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.43     *
# *............................................................................*
# *Br   94 :eta_wrtThrMissPPerp : eta_wrtThrMissPPerp[nParticle]/F             *
# *Entries :    19158 : Total  Size=    2350265 bytes  File Size  =    1363658 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.72     *
# *............................................................................*
# *Br   95 :rap_wrtThrMissPPerp : rap_wrtThrMissPPerp[nParticle]/F             *
# *Entries :    19158 : Total  Size=    2350265 bytes  File Size  =    1356532 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.73     *
# *............................................................................*
# *Br   96 :theta_wrtThrMissPPerp : theta_wrtThrMissPPerp[nParticle]/F         *
# *Entries :    19158 : Total  Size=    2350319 bytes  File Size  =    1318218 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.78     *
# *............................................................................*
# *Br   97 :phi_wrtThrMissPPerp : phi_wrtThrMissPPerp[nParticle]/F             *
# *Entries :    19158 : Total  Size=    2350265 bytes  File Size  =    1519723 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=   1.55     *
# *............................................................................*
# *Br   98 :passesArtificAccept : passesArtificAccept[nParticle]/O             *
# *Entries :    19158 : Total  Size=     645746 bytes  File Size  =     111611 *
# *Baskets :        9 : Basket Size=     210432 bytes  Compression=   5.78     *
# *............................................................................*
# *Br   99 :artificAcceptEffCorrection :                                       *
# *         | artificAcceptEffCorrection[nParticle]/F                          *
# *Entries :    19158 : Total  Size=    2350454 bytes  File Size  =     156444 *
# *Baskets :       23 : Basket Size=     659456 bytes  Compression=  15.02     *
# *............................................................................*
# *Br  100 :passesNTupleAfterCut : passesNTupleAfterCut/O                      *
# *Entries :    19158 : Total  Size=      20033 bytes  File Size  =        551 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  35.38     *
# *............................................................................*
# *Br  101 :passesTotalChgEnergyMin : passesTotalChgEnergyMin/O                *
# *Entries :    19158 : Total  Size=      20057 bytes  File Size  =        604 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  32.29     *
# *............................................................................*
# *Br  102 :passesNTrkMin : passesNTrkMin/O                                    *
# *Entries :    19158 : Total  Size=      19977 bytes  File Size  =        541 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  35.98     *
# *............................................................................*
# *Br  103 :passesSTheta : passesSTheta/O                                      *
# *Entries :    19158 : Total  Size=      19969 bytes  File Size  =       1652 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  11.78     *
# *............................................................................*
# *Br  104 :passesMissP : passesMissP/O                                        *
# *Entries :    19158 : Total  Size=      19961 bytes  File Size  =       1790 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  10.87     *
# *............................................................................*
# *Br  105 :passesISR : passesISR/O                                            *
# *Entries :    19158 : Total  Size=      19945 bytes  File Size  =       1089 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  17.86     *
# *............................................................................*
# *Br  106 :passesWW  : passesWW/O                                             *
# *Entries :    19158 : Total  Size=      19937 bytes  File Size  =       1085 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  17.92     *
# *............................................................................*
# *Br  107 :passesNeuNch : passesNeuNch/O                                      *
# *Entries :    19158 : Total  Size=      19969 bytes  File Size  =        700 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  27.80     *
# *............................................................................*
# *Br  108 :passesAll : passesAll/O                                            *
# *Entries :    19158 : Total  Size=      19945 bytes  File Size  =       2466 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=   7.89     *
# *............................................................................*
# *Br  109 :missP     : missP/F                                                *
# *Entries :    19158 : Total  Size=      77393 bytes  File Size  =      68964 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  110 :missPt    : missPt/F                                               *
# *Entries :    19158 : Total  Size=      77401 bytes  File Size  =      69210 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  111 :missTheta : missTheta/F                                            *
# *Entries :    19158 : Total  Size=      77425 bytes  File Size  =      68359 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  112 :missPhi   : missPhi/F                                              *
# *Entries :    19158 : Total  Size=      77409 bytes  File Size  =      71129 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  113 :missChargedP : missChargedP/F                                      *
# *Entries :    19158 : Total  Size=      77449 bytes  File Size  =      68871 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  114 :missChargedPt : missChargedPt/F                                    *
# *Entries :    19158 : Total  Size=      77457 bytes  File Size  =      69092 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  115 :missChargedTheta : missChargedTheta/F                              *
# *Entries :    19158 : Total  Size=      77481 bytes  File Size  =      68256 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  116 :missChargedPhi : missChargedPhi/F                                  *
# *Entries :    19158 : Total  Size=      77465 bytes  File Size  =      71269 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  117 :nChargedHadrons : nChargedHadrons/I                                *
# *Entries :    19158 : Total  Size=      77473 bytes  File Size  =      20454 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   3.76     *
# *............................................................................*
# *Br  118 :nChargedHadronsHP : nChargedHadronsHP/I                            *
# *Entries :    19158 : Total  Size=      77489 bytes  File Size  =      20333 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   3.78     *
# *............................................................................*
# *Br  119 :nChargedHadronsHP_Corrected : nChargedHadronsHP_Corrected/F        *
# *Entries :    19158 : Total  Size=      77569 bytes  File Size  =      65639 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.17     *
# *............................................................................*
# *Br  120 :nChargedHadrons_GT0p4 : nChargedHadrons_GT0p4/I                    *
# *Entries :    19158 : Total  Size=      77521 bytes  File Size  =      19716 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   3.90     *
# *............................................................................*
# *Br  121 :nChargedHadrons_GT0p4Thrust : nChargedHadrons_GT0p4Thrust/I        *
# *Entries :    19158 : Total  Size=      77569 bytes  File Size  =      19206 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   4.01     *
# *............................................................................*
# *Br  122 :Thrust    : Thrust/F                                               *
# *Entries :    19158 : Total  Size=      77401 bytes  File Size  =      63134 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  123 :TTheta    : TTheta/F                                               *
# *Entries :    19158 : Total  Size=      77401 bytes  File Size  =      67933 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  124 :TPhi      : TPhi/F                                                 *
# *Entries :    19158 : Total  Size=      77385 bytes  File Size  =      71217 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  125 :Thrust_charged : Thrust_charged/F                                  *
# *Entries :    19158 : Total  Size=      77465 bytes  File Size  =      63278 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  126 :TTheta_charged : TTheta_charged/F                                  *
# *Entries :    19158 : Total  Size=      77465 bytes  File Size  =      67923 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  127 :TPhi_charged : TPhi_charged/F                                      *
# *Entries :    19158 : Total  Size=      77449 bytes  File Size  =      71201 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  128 :Thrust_neutral : Thrust_neutral/F                                  *
# *Entries :    19158 : Total  Size=      77465 bytes  File Size  =      63266 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  129 :TTheta_neutral : TTheta_neutral/F                                  *
# *Entries :    19158 : Total  Size=      77465 bytes  File Size  =      68066 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  130 :TPhi_neutral : TPhi_neutral/F                                      *
# *Entries :    19158 : Total  Size=      77449 bytes  File Size  =      71262 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  131 :ThrustCorr : ThrustCorr/F                                          *
# *Entries :    19158 : Total  Size=      77433 bytes  File Size  =      63204 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  132 :TThetaCorr : TThetaCorr/F                                          *
# *Entries :    19158 : Total  Size=      77433 bytes  File Size  =      67953 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  133 :TPhiCorr  : TPhiCorr/F                                             *
# *Entries :    19158 : Total  Size=      77417 bytes  File Size  =      71250 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  134 :ThrustCorrInverse : ThrustCorrInverse/F                            *
# *Entries :    19158 : Total  Size=      77489 bytes  File Size  =      63210 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  135 :TThetaCorrInverse : TThetaCorrInverse/F                            *
# *Entries :    19158 : Total  Size=      77489 bytes  File Size  =      67987 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  136 :TPhiCorrInverse : TPhiCorrInverse/F                                *
# *Entries :    19158 : Total  Size=      77473 bytes  File Size  =      71276 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  137 :ThrustWithMissP : ThrustWithMissP/F                                *
# *Entries :    19158 : Total  Size=      77473 bytes  File Size  =      63300 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.22     *
# *............................................................................*
# *Br  138 :TThetaWithMissP : TThetaWithMissP/F                                *
# *Entries :    19158 : Total  Size=      77473 bytes  File Size  =      68016 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  139 :TPhiWithMissP : TPhiWithMissP/F                                    *
# *Entries :    19158 : Total  Size=      77457 bytes  File Size  =      71262 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.08     *
# *............................................................................*
# *Br  140 :Sphericity : Sphericity/F                                          *
# *Entries :    19158 : Total  Size=      77433 bytes  File Size  =      70172 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.10     *
# *............................................................................*
# *Br  141 :STheta    : STheta/F                                               *
# *Entries :    19158 : Total  Size=      77401 bytes  File Size  =      67886 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  142 :SPhi      : SPhi/F                                                 *
# *Entries :    19158 : Total  Size=      77385 bytes  File Size  =      69198 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  143 :Aplanarity : Aplanarity/F                                          *
# *Entries :    19158 : Total  Size=      77433 bytes  File Size  =      69604 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.11     *
# *............................................................................*
# *Br  144 :Sphericity_linearized : Sphericity_linearized/F                    *
# *Entries :    19158 : Total  Size=      77521 bytes  File Size  =      69033 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  145 :STheta_linearized : STheta_linearized/F                            *
# *Entries :    19158 : Total  Size=      77489 bytes  File Size  =      67948 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.13     *
# *............................................................................*
# *Br  146 :SPhi_linearized : SPhi_linearized/F                                *
# *Entries :    19158 : Total  Size=      77473 bytes  File Size  =      70323 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.09     *
# *............................................................................*
# *Br  147 :Aplanarity_linearized : Aplanarity_linearized/F                    *
# *Entries :    19158 : Total  Size=      77521 bytes  File Size  =      68811 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  148 :C_linearized : C_linearized/F                                      *
# *Entries :    19158 : Total  Size=      77449 bytes  File Size  =      68934 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.12     *
# *............................................................................*
# *Br  149 :D_linearized : D_linearized/F                                      *
# *Entries :    19158 : Total  Size=      77449 bytes  File Size  =      70615 *
# *Baskets :        4 : Basket Size=      60928 bytes  Compression=   1.09     *
# *............................................................................*
# *Br  150 :passesLEP1TwoPC : passesLEP1TwoPC/O                                *
# *Entries :    19158 : Total  Size=      19993 bytes  File Size  =       1782 *
# *Baskets :        4 : Basket Size=      45568 bytes  Compression=  10.93     *
# *............................................................................*

# %%
Canvas = ROOT.TCanvas("Canvas", "", 1024, 768)
Tree.Draw("nref")
Canvas.Draw()

# %%
#Comparison of total energy to Distance
def jetshape(inputfilename, outputfilename, JetTreename, particletreename):
    File = ROOT.TFile("LEP1Data1994P1_recons_aftercut-MERGED.root")
    outFile = ROOT.TFile(outputfilename, "recreate")
    Hist12 = ROOT.TH1D("HIST12", "Total Energy vs. Distance", 80, 0, 2)
    Counter = 0
    TreeGen = File.Get(JetTreename)
    TreeParticle = File.Get(particletreename)
    TotalNumberOfCollisions = TreeParticle.GetEntries("nParticle")
    TargetNumberOfCollisions = TotalNumberOfCollisions * 0.01
    CurrentlyProcessed = 0
    #processing event collisions
    for EventGen, ParticleGen in zip(TreeGen, TreeParticle):
         CurrentlyProcessed = CurrentlyProcessed + 1
         if CurrentlyProcessed > TargetNumberOfCollisions:
             break
         GenPX = [EventGen.jtpt[i] * math.cos(EventGen.jteta[i]) for i in range(EventGen.nref)]
         GenPY = [EventGen.jtpt[i] * math.sin(EventGen.jteta[i]) for i in range(EventGen.nref)]
         GenPZ = [EventGen.jtpt[i] * math.sinh(EventGen.jteta[i]) for i in range(EventGen.nref)]
         GenP =  [EventGen.jtpt[i] * math.cosh(EventGen.jteta[i]) for i in range(EventGen.nref)]
         GenE = [math.sqrt(EventGen.jtm[i]**2 + GenP[i]**2) for i in range(EventGen.nref)]
        #E1
         PGPX = [ParticleGen.pt[i] * math.cos(ParticleGen.eta[i]) for i in range(ParticleGen.nParticle)]
         PGPY = [ParticleGen.pt[i] * math.sin(ParticleGen.eta[i]) for i in range(ParticleGen.nParticle)]
         #print([ParticleGen.eta[i] for i in range(ParticleGen.nParticle)])
         PGPZ = [ParticleGen.pt[i] * math.sinh(100 if ParticleGen.eta[i] > 100 else (-100 if ParticleGen.eta[i] < -100 else ParticleGen.eta[i])) for i in range(ParticleGen.nParticle)]
         PGP = [ParticleGen.pt[i] * math.cosh(100 if ParticleGen.eta[i] > 100 else (-100 if ParticleGen.eta[i] < -100 else ParticleGen.eta[i])) for i in range(ParticleGen.nParticle)]
         PGE = [math.sqrt(ParticleGen.mass[i]**2 + PGP[i]**2) for i in range(ParticleGen.nParticle)]
         #E1prime
         for iG in range(len(GenPX)):
             #miscellaneous below
             # we want to do both <40 and >40 want as well 10-20; 20-30; 30-40; 40+ (R8; MCt v. MCtgen) (MCt and Datat)
             #TotalEnergy = TreeParticle.GetEntries("Energy")
             #TargetEnergy = TotalEnergy * 0.1
             #ProcessedEnergy = 0
             #ProcessedEnergy = ProcessedEnergy + 1
             #if ProcessedEnergy > TargetEnergy:
                 #break
             if GenE[iG] > 40: 
                 continue
             Counter = Counter + 1
             for iP in range(ParticleGen.nParticle):
                 if PGP[iP] == 0 or GenP[iG] == 0:
                     continue
                 Cosine = (((GenPX[iG] * PGPX[iP]) + (GenPY[iG] * PGPY[iP]) + (GenPZ[iG] * PGPZ[iP])) / (GenP[iG] * PGP[iP]))
                 if Cosine > 1: Cosine = 1
                 if Cosine < -1: Cosine = -1
                 Distance = np.arccos(Cosine)
                 if Distance < 0.8:
                     Hist12.GetXaxis().SetRangeUser(0, 0.8)
                     Hist12.Fill(Distance +random.gauss(0, 0.005), PGE[iP])
    Hist12.Scale(1 / Counter)
    for i in range (0, 80):
        r = Hist12.GetXaxis(). GetBinLowEdge(i + 1)
        R = Hist12.GetXaxis().GetBinUpEdge(i + 1)
        x = Hist12.GetBinContent(i + 1)
        Area = math.pi*(R*R - r*r)
        avg = x / Area
        Hist12.SetBinContent(i + 1, avg)
    
    Canvas = ROOT.TCanvas("Canvas", "", 1024, 768)
    #Hist2.GetXaxis().SetRangeUser(0, 0.8)
    #Hist3.GetXaxis().SetRangeUser(0, 0.8)
    Hist12.Draw()
    #Canvas.SetLogy()
    #delete previous line when doing new type of running
    outFile.cd()
    Hist12.Write()
    outFile.Close()

# %%
jetshape("LEP1Data1994P1_recons_aftercut-MERGED.root", "LEPD>40t.root", "akR8ESchemeJetTree", "t")

# %%
#Different simulations contrasted against the above code 
Canvas = ROOT.TCanvas("Canvas", "", 1024, 768)
Canvas.SetLogy()
File1 = ROOT.TFile("MC>40t.root")
#different simulation matchbox vs. sherpa vs. LEPIMC
#with and without detector effects which is LEPIMC with t and tgen two histograms
#everything under LEPIMC ALEPHMC
# with detector vs. data LEPIMC vs. LEPIData 
File2 = ROOT.TFile("LEPD>40t.root")
#File3 = ROOT.TFile("reconLEPMCtR8.root")

Hist1 = File1.Get("HIST12")
Hist2 = File2.Get("HIST12")
#Hist3 = File3.Get("HIST12")

Hist1.SetLineColor(ROOT.kBlue)
Hist2.SetLineColor(ROOT.kRed)
#Hist3.SetLineColor(ROOT.kGreen)

Legend = ROOT.TLegend(0.5, 0.8, 0.8, 0.6)
Legend.AddEntry(Hist1, "LEPMCtR8>40", "lp")
Legend.AddEntry(Hist2, "LEPDtR8>40", "lp")
#Legend.AddEntry(Hist3, "LEPMCR8", "lp")


Hist1.SetMarkerStyle(20)
Hist1.SetMarkerColor(ROOT.kBlue)
Hist2.SetMarkerStyle(20)
Hist2.SetMarkerColor(ROOT.kRed)
#Hist3.SetMarkerStyle(20)
#Hist3.SetMarkerColor(ROOT.kGreen)
Hist1.Draw();
Hist2.Draw("same")
#Hist3.Draw("same")

#Do everything with R8 and <0.8 distance 
#
Canvas.Draw()
Legend.Draw()

# %%
#part 2 finding polar angle of the particle

# %%
def GetPhi(x, y):
    if x == 0 and y > 0:
        return math.pi / 2

    if x == 0 and y < 0: 
        return (-(math.pi) / 2)

    if x > 0: 
        return np.arctan(y / x)

    if x < 0: 
        return math.pi + np.arctan(y / x)
    return 0

def jetshape(inputfilename, outputfilename, particletree1, particletree2):
    File = ROOT.TFile("LEP1MC1994_recons_aftercut-001.root")
    outFile = ROOT.TFile(outputfilename, "recreate")
    Hist12 = ROOT.TH1D("HIST12", "Total Energy vs. Distance", 80, 0, 20)
    Hist13 = ROOT.TH2D("HIST13", "E from tgen vs. E from t", 80, 0, 20, 80, 0, 20)
    Hist14 = ROOT.TH2D("HIST14", "polar theta from tgen vs. polar theta from t", 80, 0, 3.141, 80, -0.005, 0.005)
    Hist16 = ROOT.TH2D("HIST16", "azimuth from tgen vs. azimuth from t", 80, -3.141 / 2, 3.141 * 1.5, 80,-.05, 0.05)
    Counter = 0
    TreeParticle1 = File.Get(particletree1)
    TreeParticle2 = File.Get(particletree2)
    TotalNumberOfCollisions = TreeParticle1.GetEntries("nParticle")
    TargetNumberOfCollisions = TotalNumberOfCollisions * 0.01
    CurrentlyProcessed = 0
    for Event1, Event2 in zip(TreeParticle1, TreeParticle2):
         CurrentlyProcessed = CurrentlyProcessed + 1
         if CurrentlyProcessed > TargetNumberOfCollisions:
             break
        GenPX = [Event1.px[i] for i in range(Event1.nParticle)]
         GenPY = [Event1.py[i] for i in range(Event1.nParticle)]
         GenPZ = [Event1.pz[i] for i in range(Event1.nParticle)]
         GenP =  [math.sqrt(Event1.px[i] ** 2 + Event1.py[i] ** 2 + Event1.pz[i] ** 2) for i in range(Event1.nParticle)]
         GenE = [math.sqrt(Event1.mass[i]**2 + GenP[i]**2) for i in range(Event1.nParticle)]
         Gentheta = np.arccos([GenPZ[i] / math.sqrt(Event1.px[i] ** 2 + Event1.py[i] ** 2 + Event1.pz[i] ** 2) for i in range(Event1.nParticle)])
        #E1 Event1.charge[...] == 0 Event2.charge[...' ==0 all plots stay the same just adding a qualifier
         PGPX = [Event2.px[i] for i in range(Event2.nParticle)]
         PGPY = [Event2.py[i] for i in range(Event2.nParticle)]
         #print([ParticleGen.eta[i] for i in range(ParticleGen.nParticle)])
         PGPZ = [Event2.pz[i] for i in range(Event2.nParticle)]
         PGP = [math.sqrt(Event2.px[i] ** 2 + Event2.py[i] ** 2 + Event2.pz[i] ** 2) for i in range(Event2.nParticle)]
         PGE = [math.sqrt(Event2.mass[i]**2 + PGP[i]**2) for i in range(Event2.nParticle)]
         Ptheta = np.arccos([PGPZ[i] / math.sqrt(Event2.px[i] ** 2 + Event2.py[i] ** 2 + Event2.pz[i] ** 2) for i in range(Event2.nParticle)])
         #E1prime
         for iG in range(len(GenPX)):
             # we want to do both <40 and >40 want as well 10-20; 20-30; 30-40; 40+ (R8; MCt v. MCtgen) (MCtgen and Datat)
             if GenE [iG]< 1: 
                 continue
             Counter = Counter + 1
             Bestsofar = 0 
             Bestdistance = 9999
             for iP in range(Event2.nParticle):
                 if PGP[iP] == 0 or GenP[iG] == 0:
                     continue
                 Cosine = (((GenPX[iG] * PGPX[iP]) + (GenPY[iG] * PGPY[iP]) + (GenPZ[iG] * PGPZ[iP])) / (GenP[iG] * PGP[iP]))
                 if Cosine > 1: Cosine = 1
                 if Cosine < -1: Cosine = -1
                 Distance = np.arccos(Cosine)
                 if Distance < Bestdistance :
                     Bestsofar = iP
                     Bestdistance = Distance
                 Hist12.GetXaxis().SetRangeUser(0, 4)
             Hist12.Fill(Bestsofar)
             if Bestdistance < 0.04:
                 #Hist14.Fill(Gentheta[iG],Ptheta[Bestsofar] - Gentheta[iG])
                 #Hist16.Fill(GetPhi(GenPX[iG], GenPY[iG]),GetPhi( PGPX[Bestsofar], PGPY[Bestsofar]))
                 Hist16.Fill(GetPhi(GenPX[iG], GenPY[iG]),GetPhi( PGPX[Bestsofar], PGPY[Bestsofar])- GetPhi(GenPX[iG], GenPY[iG]))
    Hist12.Scale(1 / Counter)
    for i in range (0, 80):
        r = Hist12.GetXaxis(). GetBinLowEdge(i + 1)
        R = Hist12.GetXaxis().GetBinUpEdge(i + 1)
        x = Hist12.GetBinContent(i + 1)
        Area = math.pi*(R*R - r*r)
        avg = x / Area
        Hist12.SetBinContent(i + 1, avg)
    
    Canvas = ROOT.TCanvas("Canvas", "", 1024, 768)
    #Hist2.GetXaxis().SetRangeUser(0, 0.8)
    #Hist3.GetXaxis().SetRangeUser(0, 0.8)
    Hist12.Draw()
    #Canvas.SetLogy()
    #delete previous line when doing new type of running
    outFile.cd()
    Hist12.Write()
    Hist16.Write()
    outFile.Close()

#only need mct and mctgen

# goal: data
#step 2: undo detector effects 
#step 1: how big it is 
#step 3 test on simulation 
#step 4 systematic uncertainties
#need to know if simulation is similar to data

# %%
jetshape("LEP1MC1994_recons_aftercut-001.root", "MCbestdistancephi.root", "tgen", "t")

# %%
Canvas = ROOT.TCanvas("Canvas", "", 1024, 768)
#Canvas.SetLogy()
File1 = ROOT.TFile("MCbestdistancephi.root")
#different simulation matchbox vs. sherpa vs. LEPIMC
#with and without detector effects which is LEPIMC with t and tgen two histograms
#everything under LEPIMC ALEPHMC
# with detector vs. data LEPIMC vs. LEPIData 
#File2 = ROOT.TFile("reconLEPMCtgenR8.root")
#File3 = ROOT.TFile("reconLEPMCtR8.root")

Hist1 = File1.Get("HIST16")
#Hist2 = File2.Get("HIST12")
#Hist3 = File3.Get("HIST12")

Hist1.SetLineColor(ROOT.kBlue)
#Hist2.SetLineColor(ROOT.kRed)
#Hist3.SetLineColor(ROOT.kGreen)

Legend = ROOT.TLegend(1, 1, 1, 0.6)
Legend.AddEntry(Hist1, "LEPMCtR8", "lp")
#Legend.AddEntry(Hist2, "LEPMCtgenR8", "lp")
#Legend.AddEntry(Hist3, "LEPMCR8", "lp")
Hist16.projectiony

Hist1.SetMarkerStyle(20)
Hist1.SetMarkerColor(ROOT.kBlue)
#Hist2.SetMarkerStyle(20)
#Hist2.SetMarkerColor(ROOT.kRed)
#Hist3.SetMarkerStyle(20)
#Hist3.SetMarkerColor(ROOT.kGreen)
Hist1.Draw("colz");
#Hist2.Draw("same")
#Hist3.Draw("same")

#Do everything with R8 and <0.8 distance 
#
Canvas.Draw()
Legend.Draw()
